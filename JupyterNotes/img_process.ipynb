# %%
from PIL import Image

img = Image.open('/Volumes/CPSC587DATA/RecordedImg/OFF_LEFT/center_2017_10_10_16_30_47_570.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x160 at 0x116ADEE48>

# %%
import numpy as np

img_array = np.asarray(img)
img_array.shape
# Out:
# (160, 320, 3)

# %%
img_array = cv2.resize(img_array, (320, 160), cv2.INTER_AREA)
Image.fromarray(img_array)
# img_array.shape
# Out:
# <PIL.Image.Image image mode=RGB size=320x160 at 0x116AEB0F0>

# %%
img_array = img_array[60:-10, :, :]
Image.fromarray(img_array)
# Out:
# <PIL.Image.Image image mode=RGB size=320x90 at 0x116AEB080>

# %%
import cv2
IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS = 66, 200, 3
img_array = cv2.resize(img_array, (IMAGE_WIDTH, IMAGE_HEIGHT), cv2.INTER_AREA)
Image.fromarray(img_array)
# Out:
# <PIL.Image.Image image mode=RGB size=200x66 at 0x10F3B4A20>

# %%
img_array = cv2.cvtColor(img_array, cv2.COLOR_RGB2YUV)
Image.fromarray(img_array)
# Out:
# <PIL.Image.Image image mode=RGB size=200x66 at 0x116AEB128>

# %%
img_array.shape
# Out:
# (66, 200, 3)

# %%
np.reshape(img_array, (IMAGE_HEIGHT * IMAGE_WIDTH * IMAGE_CHANNELS)).shape
# Out:
# (39600,)
